# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
df = pd.read_csv('mini_comments.csv', parse_dates=True, dtype={'a': np.float64, 'b': np.int32} )
new_cols = df.columns.values
new_cols[-1] = 'rc'
df.columns  = new_cols
df[['report']].count
# Out:
# <bound method DataFrame.count of                             report
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                   Avoid politics
# 4    Keep information quality high
# 5    Keep information quality high
# 6           This is misinformation
# 7   It's rude, vulgar or offensive
# 8   It's rude, vulgar or offensive
# 9           This is misinformation
# 10          This is misinformation
# 11                  Avoid politics
# 12                        Strawman
# 13                  Avoid politics
# 14  It's rude, vulgar or offensive
# 15                             NaN
# 16   Keep information quality high
# 17                      incivility
# 18          This is misinformation
# 19               political content>

# %% [markdown]
# ## What kinds of things can you even do
#
# **Big Daddy** is coming to a theater near you

# %%
df.tail()
# Out:
#                                                     id    mod   target  \
# 169818  ModAction_b43c1060-a6e3-11ea-a50b-0ee578f2f733  bgzp1  fswqf3e
# 169819  ModAction_a8684fa6-a6e3-11ea-9467-0e8a74df3507  bgzp1  fsx8opk
# 169820  ModAction_8977bc30-a6e3-11ea-bd8b-0efb7a0742ed  bgzp1  fsxokv5
# 169821  ModAction_80ac53c4-a60a-11ea-9fe8-0eb3adc22ae7  bwh66  fsssmlx
# 169822  ModAction_75146510-a60a-11ea-b88b-0e107223a50f  bwh66  fssua5e
#
#                 action  type              created     id.1  \
# 169818  approvecomment     0  2020-06-04T23:19:10  fswqf3e
# 169819  approvecomment     0  2020-06-04T23:18:50  fsx8opk
# 169820  approvecomment     0  2020-06-04T23:17:58  fsxokv5
# 169821  approvecomment     0  2020-06-03T21:24:22  fsssmlx
# 169822   removecomment     0  2020-06-03T21:24:03  fssua5e
#
#                   created.1  \
# 169818  2020-06-04T17:14:02
# 169819  2020-06-04T19:57:00
# 169820  2020-06-04T22:31:46
# 169821  2020-06-03T17:54:38
# 169822  2020-06-03T18:08:49
#
# ...

# %%
df.dtypes
# Out:
# id                 object
# mod                object
# target             object
# action             object
# type                int64
# created            object
# id.1               object
# created.1          object
# body               object
# edited              int64
# ups                 int64
# author             object
# removal_reason     object
# id.2               object
# name               object
# id.3               object
# name.1             object
# mod_action_id      object
# report             object
# count             float64
# dtype: object

# %%
df['count'].unique()
# Out:
# array([nan, '1', '2', '5', '3', '4', '8', '6', '7', '9', 'jquiz1852',
#        'justcool393', 'JenniferColeRhuk', 'PantyPixie', 'barber5', '10',
#        'AOrangeOrange'], dtype=object)
